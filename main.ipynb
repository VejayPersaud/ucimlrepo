# %%
# %run ensemble_method.ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  target
# ...

# %%
#Summarize the performance of all models
performance = pd.concat([svm_results, grid_svm_results, nn_results, grid_nn_results, rf_results, 
                         grid_rf_results, knn_results, grid_knn_results, ensemble_results], ignore_index=True)

# remove runtime, doesnt fit on scale
performance = performance.drop(columns=['Runtime'])

#Print the performance DataFrame
print(performance.to_string(index=False))

#Pivot the DataFrame to have metrics as rows and models as columns
performance_pivot = performance.melt(id_vars='Model', var_name='Metric', value_name='Score')

#Plot the performance metrics for comparison
plt.figure(figsize=(12, 8))
sns.barplot(x='Metric', y='Score', hue='Model', data=performance_pivot)
plt.ylim(0, 1)  # Adjust the y-axis limits to reduce vertical space
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xlabel('Metric')
plt.legend(title='Model')
plt.show()
# Out:
#               Model  Accuracy  Precision   Recall       F1
#                 SVM  0.816667   0.826659 0.816667 0.815901
#      GridSearch SVM  0.850000   0.885526 0.850000 0.847339
#      Neural Network  0.833333   0.840067 0.833333 0.832963
#       GridSearch NN  0.866667   0.873850 0.866667 0.866370
#       Random Forest  0.816667   0.820461 0.816667 0.816514
#       GridSearch RF  0.850000   0.860747 0.850000 0.849373
# K-Nearest Neighbors  0.866667   0.873850 0.866667 0.866370
#      GridSearch KNN  0.800000   0.813714 0.800000 0.798661
#            Ensemble  0.883333   0.906019 0.883333 0.882191

# %%
#Summarize the runtime of all models
ensemble_results['Runtime'] = grid_svm_results['Runtime'] + grid_knn_results['Runtime'] + grid_nn_results['Runtime'] + grid_rf_results['Runtime'] + ensemble_results['Runtime']
performance = pd.concat([svm_results, grid_svm_results, nn_results, grid_nn_results, rf_results, 
                         grid_rf_results, knn_results, grid_knn_results, ensemble_results], ignore_index=True)

# remove runtime, doesnt fit on scale
performance = performance.drop(columns=['Accuracy', 'Precision', 'Recall', 'F1'])

#Print the performance DataFrame
print(performance.to_string(index=False))

#Pivot the DataFrame to have metrics as rows and models as columns
performance_pivot = performance.melt(id_vars='Model', var_name='Metric', value_name='Score')

#Plot the performance metrics for comparison
plt.figure(figsize=(12, 8))
sns.barplot(x='Metric', y='Score', hue='Model', data=performance_pivot)
plt.title('Model Training Runtime Comparison')
plt.ylabel('Runtime')
plt.yscale('log')
plt.xlabel('Model')
plt.legend(title='Model')
plt.show()
# Out:
#               Model    Runtime
#                 SVM   0.005956
#      GridSearch SVM   5.541965
#      Neural Network   0.184018
#       GridSearch NN  66.132680
#       Random Forest   0.060248
#       GridSearch RF 112.664554
# K-Nearest Neighbors   0.000430
#      GridSearch KNN   0.197851
#            Ensemble 186.061371
